# %%
import urllib.request
import pandas as pd
import json

# %%
df_bibliothek = json.load(open("Bibliothek.json"))
df_medizin = json.load(open("Medizin.json"))
df_musik = json.load(open("Musik.json"))
df_cat = json.load(open("cat.json"))
df_kunst = json.load(open("kunst.json"))
df_wool = json.load(open("wool.json"))


# nicht über merge sonder über die Variante, die in den Videotutorial vorgestellt 
# wurde unter "Daten zusammenführen"

# %%
df_bibliothek_selection = pd.DataFrame(df_bibliothek["items"])
df_medizin_selection = pd.DataFrame(df_medizin["items"])
df_musik_selection = pd.DataFrame(df_musik["items"])
df_cat_selection = pd.DataFrame(df_cat["items"])
df_kunst_selection = pd.DataFrame(df_kunst["items"])
df_wool_selection = pd.DataFrame(df_wool["items"])


# Erstellen der DataFrames aus den Listen der Dictionaries, die die Dateneinträge der Bibsonomy Suche darstellen

# %%
df_bibliothek_selection = df_bibliothek_selection.rename(columns={"label": "title_bib"})

# %%
df_bibliothek_selection["key"] = "bibliothek"

# %%
df_medizin_selection["key"] = "medizin"

# %%
df_cat_selection["key"] = "cat"

# %%
df_kunst_selection["key"] = "kunst"

# %%
df_wool_selection["key"] = "Wolle"

# %%
df_musik_selection["key"] = "musik"

# in den letzten Befehlen wurden die Suchtermini hinzugefügt

# %%
df_bib = df_bibliothek_selection
df_med = df_medizin_selection
df_mus = df_musik_selection
df_cat = df_cat_selection
df_art = df_kunst_selection
df_woo = df_wool_selection

# %%
data = pd.concat([df_bib, df_med, df_mus, df_cat, df_art, df_woo], ignore_index=True)
data
# Out:
#               type                                                 id  \
# 0         Bookmark  https://www.bibsonomy.org/url/8dccb0fb43c1baa0...
# 1         Bookmark  https://www.bibsonomy.org/url/1a69c31da5d74f35...
# 2         Bookmark  https://www.bibsonomy.org/url/6e4d27522857a23d...
# 3         Bookmark  https://www.bibsonomy.org/url/ee0c998028ff077b...
# 4         Bookmark  https://www.bibsonomy.org/url/561cc0370c975e9d...
# ...            ...                                                ...
# 11995  Publication  https://www.bibsonomy.org/bibtex/2264f06d787e9...
# 11996  Publication  https://www.bibsonomy.org/bibtex/27fff9d054c3c...
# 11997  Publication  https://www.bibsonomy.org/bibtex/2fca8d3eef328...
# 11998  Publication  https://www.bibsonomy.org/bibtex/27577f44b5f2b...
# 11999  Publication  https://www.bibsonomy.org/bibtex/2c19a0a12c534...
#
#                                                     tags  \
# 0                               [bibliothek, treffpunkt]
# 1         [bibliothek, tech, onleihe, bibliothek20, drm]
# 2                                           [Bibliothek]
# 3                        [bibliothek, importmw, inetbib]
# 4      [bibliothek, wirtschaftswissenschaften, inform...
# ...                                                  ...
# 11995  [cause_effect_interdependencies, tool_logistic...
# 11996             [PICO, question_answering, biomedical]
# 11997                                             [dblp]
# 11998                                   [myown, se, UML]
# 11999  [Trees, Plants, Wood, Yielding, Host, Jungle, ...
#
#                               intraHash  \
# 0      8dccb0fb43c1baa049c04533af10c807
# 1      1a69c31da5d74f35e53a07e3ed2c756f
# 2      6e4d27522857a23d27d0fc781601e288
# 3      ee0c998028ff077b8d2417cd512980f0
# 4      561cc0370c975e9d9143e81e9d901138
# ...                                 ...
# 11995  264f06d787e96f6a060b9ea7a0d5f354
# 11996  7fff9d054c3c86a475fb9fda29e9a905
# 11997  fca8d3eef328459b0430fa6f43f7055d
# 11998  7577f44b5f2b1c1a6ffd8d0a396e26a7
# 11999  c19a0a12c534e5151ebfdf2c52bbfcf4
#
#                                                title_bib            user  \
# 0                      Bibliothek: Treffpunkt Bibliothek           hotho
# 1      onleihe: Digitale Bibliothek 0.5 « Bibliothek ...              ch
# 2                                             Bibliothek     stadlmairma
# 3      Bibliothek 1.0, 2.0 oder 3.0?  Steuereules Weblog     textundblog
# 4                              Bibliothek - Fit4Research           wdees
# ...                                                  ...             ...
# 11995                                                NaN      ideseditor
# 11996                                                NaN        diego_ma
# 11997                                                NaN            dblp
# 11998                                                NaN        zuendorf
# 11999                                                NaN  sciencejournal
#
#                                              description                 date  \
# 0           Treffpunkt Bibliothek 24. - 31. Oktober 2010  2010-07-18 21:30:25
# 1                                                         2007-07-14 00:29:30
# 2                                                         2020-09-22 15:08:13
# 3      Der Beitrag von Prof. Schneider war mit litera...  2013-06-28 16:42:01
# 4                                                         2016-05-09 12:23:32
# ...                                                  ...                  ...
# 11995                                                     2013-09-10 08:32:30
# 11996                                                     2009-08-28 21:46:37
# 11997                                                     2019-06-02 00:00:00
# 11998                                                     2011-04-18 14:33:03
# 11999                                                     2014-08-16 09:29:57
#
#                 changeDate  count  ... sortname sorttitle pubmedid address-de  \
# 0      2010-07-18 21:30:25      1  ...      NaN       NaN      NaN        NaN
# 1      2008-01-10 12:52:59      2  ...      NaN       NaN      NaN        NaN
# 2      2020-10-04 17:04:00      1  ...      NaN       NaN      NaN        NaN
# 3      2013-06-28 16:42:01      1  ...      NaN       NaN      NaN        NaN
# 4      2016-05-09 12:23:32      2  ...      NaN       NaN      NaN        NaN
# ...                    ...    ...  ...      ...       ...      ...        ...
# 11995  2013-09-10 08:32:30      1  ...      NaN       NaN      NaN        NaN
# 11996  2009-08-28 21:46:37      2  ...      NaN       NaN      NaN        NaN
# 11997  2019-06-04 13:25:30      1  ...      NaN       NaN      NaN        NaN
# 11998  2011-04-18 14:33:03      2  ...      NaN       NaN      NaN        NaN
# 11999  2014-08-16 09:29:57      1  ...      NaN       NaN      NaN        NaN
#
#       endnotereftype abstractnote place optnote session paperid
# 0                NaN          NaN   NaN     NaN     NaN     NaN
# 1                NaN          NaN   NaN     NaN     NaN     NaN
# 2                NaN          NaN   NaN     NaN     NaN     NaN
# 3                NaN          NaN   NaN     NaN     NaN     NaN
# 4                NaN          NaN   NaN     NaN     NaN     NaN
# ...              ...          ...   ...     ...     ...     ...
# 11995            NaN          NaN   NaN     NaN     NaN     NaN
# 11996            NaN          NaN   NaN     NaN     NaN     NaN
# 11997            NaN          NaN   NaN     NaN     NaN     NaN
# 11998            NaN          NaN   NaN     NaN     NaN     NaN
# 11999            NaN          NaN   NaN     NaN     NaN     NaN
#
# [12000 rows x 205 columns]

# %%
data.columns
# Out:
# Index(['type', 'id', 'tags', 'intraHash', 'title_bib', 'user', 'description',
#        'date', 'changeDate', 'count',
#        ...
#        'sortname', 'sorttitle', 'pubmedid', 'address-de', 'endnotereftype',
#        'abstractnote', 'place', 'optnote', 'session', 'paperid'],
#       dtype='object', length=205)

# %% [markdown]
# # Erstellung des Exportformats

# %%
df_data = data[["label", "author", "publisher","year", "type", "key"]]
df_data
# Out:
#                                                    label  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995  Simulative study of cause-effect interdependen...
# 11996  Evaluation of PICO as a Knowledge Representati...
# 11997  Machine Learning as Surrogate to Building Perf...
# 11998  UML1.4 to 2.1 Activity Diagram Model Migration...
# 11999  Studies On Host Range Of The Cuscuta Reflexa R...
#
#                                                  author publisher  year  \
# 0                                                   NaN       NaN   NaN
# 1                                                   NaN       NaN   NaN
# 2                                                   NaN       NaN   NaN
# 3                                                   NaN       NaN   NaN
# 4                                                   NaN       NaN   NaN
# ...                                                 ...       ...   ...
# 11995        [Rouven Nickel Anis Selaouti, Jens Knigge]       NaN  2010
# 11996    [Xiaoli Huang, Jimmy Lin, Dina Demner-Fushman]       NaN  2006
# 11997  [Sokratis Papadopoulos, Wei Lee Woon, Elie Azar]  Springer  2018
# 11998       [Ruben Jubeh, Andreas Koch, Albert Zündorf]       NaN  2010
# 11999             [Nagalakshmi Devamma M, Venu Gopal A]       NaN  2013
#
#               type         key
# 0         Bookmark  bibliothek
# 1         Bookmark  bibliothek
# 2         Bookmark  bibliothek
# 3         Bookmark  bibliothek
# 4         Bookmark  bibliothek
# ...            ...         ...
# 11995  Publication       Wolle
# 11996  Publication       Wolle
# 11997  Publication       Wolle
# 11998  Publication       Wolle
# 11999  Publication       Wolle
#
# [12000 rows x 6 columns]

# %%
df_data = df_data.loc[df_data["author"].isnull() == False]
df_data = df_data.loc[df_data["label"].isnull() == False]

# Daten auswählen, in denen ein Wert (ausgewählte Spalte) eingetragen ist.

# %%
df_data
# Out:
#                                                    label  \
# 3000                                             MEDLINE
# 3001         Heilkunde/Medizin I. Religionsgeschichtlich
# 3002                         Medizin und Systemforschung
# 3003        Bibliometrie 2.0 – Altmetrics in der Medizin
# 3004                             Wissensbasierte Medizin
# ...                                                  ...
# 11995  Simulative study of cause-effect interdependen...
# 11996  Evaluation of PICO as a Knowledge Representati...
# 11997  Machine Learning as Surrogate to Building Perf...
# 11998  UML1.4 to 2.1 Activity Diagram Model Migration...
# 11999  Studies On Host Range Of The Cuscuta Reflexa R...
#
#                                                  author  \
# 3000                                [ Medizin Forum AG]
# 3001                                       [P. Gerlitz]
# 3002                                               [ ?]
# 3003                                    [Michaele Adam]
# 3004                                 [Hermann Requardt]
# ...                                                 ...
# 11995        [Rouven Nickel Anis Selaouti, Jens Knigge]
# 11996    [Xiaoli Huang, Jimmy Lin, Dina Demner-Fushman]
# 11997  [Sokratis Papadopoulos, Wei Lee Woon, Elie Azar]
# 11998       [Ruben Jubeh, Andreas Koch, Albert Zündorf]
# 11999             [Nagalakshmi Devamma M, Venu Gopal A]
#
#                                          publisher  year         type      key
# 3000                                           NaN  2010  Publication  medizin
# 3001                                           NaN  1985  Publication  medizin
# 3002   Ges. für Systemberatung im Gesundheitswesen  1988  Publication  medizin
# 3003                                           NaN  2014  Publication  medizin
# 3004                                           NaN  2011  Publication  medizin
# ...                                            ...   ...          ...      ...
# 11995                                          NaN  2010  Publication    Wolle
# 11996                                          NaN  2006  Publication    Wolle
# 11997                                     Springer  2018  Publication    Wolle
# 11998                                          NaN  2010  Publication    Wolle
# 11999                                          NaN  2013  Publication    Wolle
#
# [4864 rows x 6 columns]

# %%
df_data.loc[df_data.type == "Publication"]

# Ausgabe aller Spalten die type = Publication sind
# Out:
#                                                    label  \
# 3000                                             MEDLINE
# 3001         Heilkunde/Medizin I. Religionsgeschichtlich
# 3002                         Medizin und Systemforschung
# 3003        Bibliometrie 2.0 – Altmetrics in der Medizin
# 3004                             Wissensbasierte Medizin
# ...                                                  ...
# 11995  Simulative study of cause-effect interdependen...
# 11996  Evaluation of PICO as a Knowledge Representati...
# 11997  Machine Learning as Surrogate to Building Perf...
# 11998  UML1.4 to 2.1 Activity Diagram Model Migration...
# 11999  Studies On Host Range Of The Cuscuta Reflexa R...
#
#                                                  author  \
# 3000                                [ Medizin Forum AG]
# 3001                                       [P. Gerlitz]
# 3002                                               [ ?]
# 3003                                    [Michaele Adam]
# 3004                                 [Hermann Requardt]
# ...                                                 ...
# 11995        [Rouven Nickel Anis Selaouti, Jens Knigge]
# 11996    [Xiaoli Huang, Jimmy Lin, Dina Demner-Fushman]
# 11997  [Sokratis Papadopoulos, Wei Lee Woon, Elie Azar]
# 11998       [Ruben Jubeh, Andreas Koch, Albert Zündorf]
# 11999             [Nagalakshmi Devamma M, Venu Gopal A]
#
#                                          publisher  year         type      key
# 3000                                           NaN  2010  Publication  medizin
# 3001                                           NaN  1985  Publication  medizin
# 3002   Ges. für Systemberatung im Gesundheitswesen  1988  Publication  medizin
# 3003                                           NaN  2014  Publication  medizin
# 3004                                           NaN  2011  Publication  medizin
# ...                                            ...   ...          ...      ...
# 11995                                          NaN  2010  Publication    Wolle
# 11996                                          NaN  2006  Publication    Wolle
# 11997                                     Springer  2018  Publication    Wolle
# 11998                                          NaN  2010  Publication    Wolle
# 11999                                          NaN  2013  Publication    Wolle
#
# [4864 rows x 6 columns]

# %%
df_data = df_data.rename(columns={"label": "title", "author": "authors"})
df_data
# Out:
#                                                    title  \
# 3000                                             MEDLINE
# 3001         Heilkunde/Medizin I. Religionsgeschichtlich
# 3002                         Medizin und Systemforschung
# 3003        Bibliometrie 2.0 – Altmetrics in der Medizin
# 3004                             Wissensbasierte Medizin
# ...                                                  ...
# 11995  Simulative study of cause-effect interdependen...
# 11996  Evaluation of PICO as a Knowledge Representati...
# 11997  Machine Learning as Surrogate to Building Perf...
# 11998  UML1.4 to 2.1 Activity Diagram Model Migration...
# 11999  Studies On Host Range Of The Cuscuta Reflexa R...
#
#                                                 authors  \
# 3000                                [ Medizin Forum AG]
# 3001                                       [P. Gerlitz]
# 3002                                               [ ?]
# 3003                                    [Michaele Adam]
# 3004                                 [Hermann Requardt]
# ...                                                 ...
# 11995        [Rouven Nickel Anis Selaouti, Jens Knigge]
# 11996    [Xiaoli Huang, Jimmy Lin, Dina Demner-Fushman]
# 11997  [Sokratis Papadopoulos, Wei Lee Woon, Elie Azar]
# 11998       [Ruben Jubeh, Andreas Koch, Albert Zündorf]
# 11999             [Nagalakshmi Devamma M, Venu Gopal A]
#
#                                          publisher  year         type      key
# 3000                                           NaN  2010  Publication  medizin
# 3001                                           NaN  1985  Publication  medizin
# 3002   Ges. für Systemberatung im Gesundheitswesen  1988  Publication  medizin
# 3003                                           NaN  2014  Publication  medizin
# 3004                                           NaN  2011  Publication  medizin
# ...                                            ...   ...          ...      ...
# 11995                                          NaN  2010  Publication    Wolle
# 11996                                          NaN  2006  Publication    Wolle
# 11997                                     Springer  2018  Publication    Wolle
# 11998                                          NaN  2010  Publication    Wolle
# 11999                                          NaN  2013  Publication    Wolle
#
# [4864 rows x 6 columns]

# %%
df_data = df_data.drop_duplicates(subset ="title", keep="first")
df_data

# Duplikate entfernt
# Out:
#                                                    title  \
# 3000                                             MEDLINE
# 3001         Heilkunde/Medizin I. Religionsgeschichtlich
# 3002                         Medizin und Systemforschung
# 3003        Bibliometrie 2.0 – Altmetrics in der Medizin
# 3004                             Wissensbasierte Medizin
# ...                                                  ...
# 11995  Simulative study of cause-effect interdependen...
# 11996  Evaluation of PICO as a Knowledge Representati...
# 11997  Machine Learning as Surrogate to Building Perf...
# 11998  UML1.4 to 2.1 Activity Diagram Model Migration...
# 11999  Studies On Host Range Of The Cuscuta Reflexa R...
#
#                                                 authors  \
# 3000                                [ Medizin Forum AG]
# 3001                                       [P. Gerlitz]
# 3002                                               [ ?]
# 3003                                    [Michaele Adam]
# 3004                                 [Hermann Requardt]
# ...                                                 ...
# 11995        [Rouven Nickel Anis Selaouti, Jens Knigge]
# 11996    [Xiaoli Huang, Jimmy Lin, Dina Demner-Fushman]
# 11997  [Sokratis Papadopoulos, Wei Lee Woon, Elie Azar]
# 11998       [Ruben Jubeh, Andreas Koch, Albert Zündorf]
# 11999             [Nagalakshmi Devamma M, Venu Gopal A]
#
#                                          publisher  year         type      key
# 3000                                           NaN  2010  Publication  medizin
# 3001                                           NaN  1985  Publication  medizin
# 3002   Ges. für Systemberatung im Gesundheitswesen  1988  Publication  medizin
# 3003                                           NaN  2014  Publication  medizin
# 3004                                           NaN  2011  Publication  medizin
# ...                                            ...   ...          ...      ...
# 11995                                          NaN  2010  Publication    Wolle
# 11996                                          NaN  2006  Publication    Wolle
# 11997                                     Springer  2018  Publication    Wolle
# 11998                                          NaN  2010  Publication    Wolle
# 11999                                          NaN  2013  Publication    Wolle
#
# [4541 rows x 6 columns]

# %%
df_data["year"].unique()
# Out:
# array(['2010', '1985', '1988', '2014', '2011', '1959', '2015', '2008',
#        '1974', '2006', '2018', '1996', '2002', '2007', '2001', '1978',
#        '1973', '2013', '1989', '1971', '2003', '1972', '2005', '1993',
#        '1992', '1946', '1962', '1966', '1982', '1969', '1955', '1997',
#        '1994', '2009', '1979', '1984', '1953', '1952', '1960', '1983',
#        '1958', '1950', '1975', '1970', '1951', '1991', '1986', '1980',
#        '2004', '1961', '2012', '2000', '1956', '1990', '1976', '1977',
#        '2021', '1963', '1948', '1965', '1964', '1922', '1942', '1995',
#        '1987', '1967', '1981', '1944', '1968', '1937', '1999', '1923',
#        '1943', '1925', '1934', '1949', '1998', '1947', '1954', '1918',
#        '1945', '1904', '2016', '1936', '1919', '1938', '1928', '1940',
#        '1939', '1929', '2023', '2022', 'Stuttgart Weimar 2000', '1927',
#        '1863', '2024', '15.Januar 2006', '2017', '1866', '1896', '1924',
#        '1941', '1930', '2020', '2019', '-', '1957', 'o.J.', '1995  ',
#        ' 2012 ', ' 1996 ', ' 2008 ', ' 2002 ', 'c2011', '1917', '1726',
#        '1913', '1933', '1921', '1931', '1914', '1935', ' 2007 ', '1915',
#        '1932', '25.11.2006', '1910', ' 2001 ', '1920', '1916', '1907',
#        'in press', 'Sept. 2001'], dtype=object)

# %%
df_data["year_correct"] = df_data.apply(lambda row: row.year.isdigit(), axis=1)
# Out:
# /tmp/ipykernel_5513/3657308115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data["year_correct"] = df_data.apply(lambda row: row.year.isdigit(), axis=1)

# %%
df_data.loc[df_data.year_correct ==False]

# Beide Befehle dienen dazu, die Werte die keine Jahreszahlen enthalten zu identifizieren
# Out:
#                                                    title  \
# 5064   Musik-Verstehen jenseits der Sprache. Zum Meta...
# 5836                                   Musik im Internet
# 7091                         TECHNICAL GUIDE Cat No. 91R
# 9002   Medien - Kunst / Kunst - Medien. Vorformen der...
# 9006             Kunst und Zufall: Analyse und Bedeutung
# 9007   Real/Medial. Hybride Prozesse zwischen Kunst u...
# 9015   Fernsehen - Kunst oder Antikunst? Konflikte un...
# 9043   Interaktion, Partizipation, Vernetzung. Kunst ...
# 9054   Kunst - Brauchen wir Kunst? Eine Überlegung au...
# 9076                        Meilensteine der Medienkunst
# 9078                                           Audio Art
# 9079   Virtuelle Narrationen. Von der Krise des Erzäh...
# 9082   Form Follows Format. Zum Spannungsverhältnis v...
# 9083   Immersion und Interaktion. Vom Rundfresko zum ...
# 9084   Raum Zeit Technikkonstruktionen. Aspekte der W...
# 9086   Einführung. Medienkunst muss multimedial vermi...
# 9116   Kunst: Text-Offensive der Documenta-Chefin Cat...
# 9121   Die Schwarze Kunst im Eichsfeld, aus der Gesch...
# 9154   Kunst - Zwischen Kassel und Kabul. Was bringt ...
# 9155   Hörbuch: Documenta, Rundfunk und der HörVerlag...
# 9173                                An die Kunst glauben
# 9384   KUNST, BÜHNE & VIDEOTAPES - Ehret den Oberlehr...
# 9542   Wissenschaft und Traum::  Legitimierung von Wi...
# 9688   Kunst: Der Author über den kunstlosen Vorlauf ...
# 9864   KULTUR - Kunst - Die documenta 12 in Kassel po...
# 11770  Collaborative Tagging as a Knowledge Organisat...
# 11913  PLTO: A Link-Time Optimizer for the Intel IA-3...
#
#                                                  authors  \
# 5064                                 [Simone Mahrenholz]
# 5836                           [Amke Block, Pohl Gerrit]
# 7091                                    [NGK Insulators]
# 9002                                    [Dieter Daniels]
# 9006                                 [Christian Janecke]
# 9007                                   [Rudolf Frieling]
# 9015                                    [Dieter Daniels]
# 9043                                         [Inke Arns]
# 9054                                   [Christoph Menke]
# 9076                   [Rudolf Frieling, Dieter Daniels]
# 9078                                      [Golo Föllmer]
# 9079                                       [Söke Dinkla]
# 9082                                   [Rudolf Frieling]
# 9083                                       [Oliver Grau]
# 9084                                     [Heike Helfert]
# 9086                   [Rudolf Frieling, Dieter Daniels]
# 9116                                        [ Unbekannt]
# 9121                                     [Manuel Müller]
# 9154                                       [Stefan Orth]
# 9155                                        [ Unbekannt]
# 9173                                  [Wolfgang Ullrich]
# 9384                                     [Bert Rebhandl]
# 9542                              [Albert Schirrmeister]
# 9688                                    [Petra Kipphoff]
# 9864                                        [ Unbekannt]
# 11770                 [George Macgregor, Emma McCulloch]
# 11913  [Benjamin Schwarz Saumya Debray, Gregory Andrews]
#
#                      publisher                   year         type    key  \
# 5064                       NaN  Stuttgart Weimar 2000  Publication  musik
# 5836                       NaN         15.Januar 2006  Publication  musik
# 7091                       NaN                      -  Publication    cat
# 9002                       NaN                   o.J.  Publication  kunst
# 9006   Verl. für Moderne Kunst                 1995    Publication  kunst
# 9007                       NaN                   o.J.  Publication  kunst
# 9015                       NaN                   o.J.  Publication  kunst
# 9043                       NaN                   o.J.  Publication  kunst
# 9054                       NaN                  2012   Publication  kunst
# 9076                       NaN                   o.J.  Publication  kunst
# 9078                       NaN                   o.J.  Publication  kunst
# 9079                       NaN                   o.J.  Publication  kunst
# 9082                       NaN                   o.J.  Publication  kunst
# 9083                       NaN                   o.J.  Publication  kunst
# 9084                       NaN                   o.J.  Publication  kunst
# 9086                       NaN                   o.J.  Publication  kunst
# 9116                       NaN                  1996   Publication  kunst
# 9121                     Mecke                  2008   Publication  kunst
# 9154                       NaN                  2012   Publication  kunst
# 9155                       NaN                  2002   Publication  kunst
# 9173                 Wagenbach                  c2011  Publication  kunst
# 9384                       NaN                  2007   Publication  kunst
# 9542                       NaN             25.11.2006  Publication  kunst
# 9688                       NaN                  2001   Publication  kunst
# 9864                       NaN                  2007   Publication  kunst
# 11770                      NaN               in press  Publication  Wolle
# 11913                      NaN             Sept. 2001  Publication  Wolle
#
#        year_correct
# 5064          False
# 5836          False
# 7091          False
# 9002          False
# 9006          False
# 9007          False
# 9015          False
# 9043          False
# 9054          False
# 9076          False
# 9078          False
# 9079          False
# 9082          False
# 9083          False
# 9084          False
# 9086          False
# 9116          False
# 9121          False
# 9154          False
# 9155          False
# 9173          False
# 9384          False
# 9542          False
# 9688          False
# 9864          False
# 11770         False
# 11913         False

# %%
df_data = df_data.loc[df_data.year_correct == True]
df_data
# Out:
#                                                    title  \
# 3000                                             MEDLINE
# 3001         Heilkunde/Medizin I. Religionsgeschichtlich
# 3002                         Medizin und Systemforschung
# 3003        Bibliometrie 2.0 – Altmetrics in der Medizin
# 3004                             Wissensbasierte Medizin
# ...                                                  ...
# 11995  Simulative study of cause-effect interdependen...
# 11996  Evaluation of PICO as a Knowledge Representati...
# 11997  Machine Learning as Surrogate to Building Perf...
# 11998  UML1.4 to 2.1 Activity Diagram Model Migration...
# 11999  Studies On Host Range Of The Cuscuta Reflexa R...
#
#                                                 authors  \
# 3000                                [ Medizin Forum AG]
# 3001                                       [P. Gerlitz]
# 3002                                               [ ?]
# 3003                                    [Michaele Adam]
# 3004                                 [Hermann Requardt]
# ...                                                 ...
# 11995        [Rouven Nickel Anis Selaouti, Jens Knigge]
# 11996    [Xiaoli Huang, Jimmy Lin, Dina Demner-Fushman]
# 11997  [Sokratis Papadopoulos, Wei Lee Woon, Elie Azar]
# 11998       [Ruben Jubeh, Andreas Koch, Albert Zündorf]
# 11999             [Nagalakshmi Devamma M, Venu Gopal A]
#
#                                          publisher  year         type  \
# 3000                                           NaN  2010  Publication
# 3001                                           NaN  1985  Publication
# 3002   Ges. für Systemberatung im Gesundheitswesen  1988  Publication
# 3003                                           NaN  2014  Publication
# 3004                                           NaN  2011  Publication
# ...                                            ...   ...          ...
# 11995                                          NaN  2010  Publication
# 11996                                          NaN  2006  Publication
# 11997                                     Springer  2018  Publication
# 11998                                          NaN  2010  Publication
# 11999                                          NaN  2013  Publication
#
#            key  year_correct
# 3000   medizin          True
# 3001   medizin          True
# 3002   medizin          True
# 3003   medizin          True
# 3004   medizin          True
# ...        ...           ...
# 11995    Wolle          True
# 11996    Wolle          True
# 11997    Wolle          True
# 11998    Wolle          True
# 11999    Wolle          True
#
# [4514 rows x 7 columns]

# %%
df_data["year_number"] = df_data["year"].astype(int)
# Out:
# /tmp/ipykernel_5513/2818441379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data["year_number"] = df_data["year"].astype(int)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4514 entries, 3000 to 11999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         4514 non-null   object
#  1   authors       4514 non-null   object
#  2   publisher     1074 non-null   object
#  3   year          4514 non-null   object
#  4   type          4514 non-null   object
#  5   key           4514 non-null   object
#  6   year_correct  4514 non-null   bool
#  7   year_number   4514 non-null   int64
# dtypes: bool(1), int64(1), object(6)
# memory usage: 286.5+ KB

# %%
df_data = df_data.loc[df_data.year_number <=2000]

# %%
df_data
# Out:
#                                                    title  \
# 3001         Heilkunde/Medizin I. Religionsgeschichtlich
# 3002                         Medizin und Systemforschung
# 3005   Medizin und Arzt bei den griechischen Kirchenv...
# 3010                          Gewerkschaften und Medizin
# 3019   Anwendung der "Virtuellen Realität" in der Med...
# ...                                                  ...
# 11954  Simulative study on the performance improvemen...
# 11966             Incl: A Tool to Analyze Include Files.
# 11972  A Performance Advisor Tool for Shared-Memory P...
# 11978  Science of Coercion: Communication Research an...
# 11985  Determining optimal scales for edge detection ...
#
#                                                authors  \
# 3001                                      [P. Gerlitz]
# 3002                                              [ ?]
# 3005                                    [H. J. Frings]
# 3010                                              [ ?]
# 3019             [Gabriele Faulkner, Thomas Tolxdorff]
# ...                                                ...
# 11954  [Chang-Wook Bae, Young-Woon Kim, Jung-Bong Suk]
# 11966                   [Kiem-Phong Vo, Yih-Farn Chen]
# 11972   [Seon Wook Kim, Insung Park, Rudolf Eigenmann]
# 11978                            [Christopher Simpson]
# 11985        [Hong Jeong, Chang-Ik Kim, Woon-Tack Woo]
#
#                                          publisher  year         type  \
# 3001                                           NaN  1985  Publication
# 3002   Ges. für Systemberatung im Gesundheitswesen  1988  Publication
# 3005                                           NaN  1959  Publication
# 3010    Verl. für das Studium der Arbeiterbewegung  1974  Publication
# 3019                            MMV Medizin Verlag  1996  Publication
# ...                                            ...   ...          ...
# 11954                                          NaN  1997  Publication
# 11966                           USENIX Association  1992  Publication
# 11972                                     Springer  2000  Publication
# 11978                      Oxford University Press  1994  Publication
# 11985                        IEEE Computer Society  1991  Publication
#
#            key  year_correct  year_number
# 3001   medizin          True         1985
# 3002   medizin          True         1988
# 3005   medizin          True         1959
# 3010   medizin          True         1974
# 3019   medizin          True         1996
# ...        ...           ...          ...
# 11954    Wolle          True         1997
# 11966    Wolle          True         1992
# 11972    Wolle          True         2000
# 11978    Wolle          True         1994
# 11985    Wolle          True         1991
#
# [2176 rows x 8 columns]

# %%
df_data = df_data.dropna()

# %%
df_data
# Out:
#                                                    title  \
# 3002                         Medizin und Systemforschung
# 3010                          Gewerkschaften und Medizin
# 3019   Anwendung der "Virtuellen Realität" in der Med...
# 3025                              Medizin im Sozialstaat
# 3030    Der vegetabile Patient und die Ethik der Medizin
# ...                                                  ...
# 11951  Local exhaustive testing: a software reliabili...
# 11966             Incl: A Tool to Analyze Include Files.
# 11972  A Performance Advisor Tool for Shared-Memory P...
# 11978  Science of Coercion: Communication Research an...
# 11985  Determining optimal scales for edge detection ...
#
#                                                 authors  \
# 3002                                               [ ?]
# 3010                                               [ ?]
# 3019              [Gabriele Faulkner, Thomas Tolxdorff]
# 3025                                      [Horst Baier]
# 3030                                  [Baruch A. Brody]
# ...                                                 ...
# 11951  [Thomas Wood, Keith W. Miller, Robert E. Noonan]
# 11966                    [Kiem-Phong Vo, Yih-Farn Chen]
# 11972    [Seon Wook Kim, Insung Park, Rudolf Eigenmann]
# 11978                             [Christopher Simpson]
# 11985         [Hong Jeong, Chang-Ik Kim, Woon-Tack Woo]
#
#                                          publisher  year         type  \
# 3002   Ges. für Systemberatung im Gesundheitswesen  1988  Publication
# 3010    Verl. für das Studium der Arbeiterbewegung  1974  Publication
# 3019                            MMV Medizin Verlag  1996  Publication
# 3025                                          Enke  1978  Publication
# 3030                                        Reclam  1989  Publication
# ...                                            ...   ...          ...
# 11951                                          ACM  1992  Publication
# 11966                           USENIX Association  1992  Publication
# 11972                                     Springer  2000  Publication
# 11978                      Oxford University Press  1994  Publication
# 11985                        IEEE Computer Society  1991  Publication
#
#            key  year_correct  year_number
# 3002   medizin          True         1988
# 3010   medizin          True         1974
# 3019   medizin          True         1996
# 3025   medizin          True         1978
# 3030   medizin          True         1989
# ...        ...           ...          ...
# 11951    Wolle          True         1992
# 11966    Wolle          True         1992
# 11972    Wolle          True         2000
# 11978    Wolle          True         1994
# 11985    Wolle          True         1991
#
# [272 rows x 8 columns]

# %%
df_data["key"].unique()

# Finde ich eigentlich ganz interessant, dass von den ganzen geladenen
# Inhalten nur diese df anscheinend Inhalte hatten
# Out:
# array(['medizin', 'musik', 'cat', 'kunst', 'Wolle'], dtype=object)

# %%
df_data.to_json("results_M2-1.json", orient="records")

# %%
with open("results_M2-1.json", "r") as f:
    j_load = json.load(f)
    print(json.dumps(j_load, indent=2))
# Out:
# [
#   {
#     "title": "Medizin und Systemforschung",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Ges. f\u00fcr Systemberatung im Gesundheitswesen",
#     "year": "1988",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Gewerkschaften und Medizin",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Verl. f\u00fcr das Studium der Arbeiterbewegung",
#     "year": "1974",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1974
#   },
#   {
#     "title": "Anwendung der \"Virtuellen Realit\u00e4t\" in der Medizin.",
#     "authors": [
#       "Gabriele Faulkner",
#       "Thomas Tolxdorff"
#     ],
#     "publisher": "MMV Medizin Verlag",
#     "year": "1996",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Medizin im Sozialstaat",
#     "authors": [
#       "Horst Baier"
#     ],
#     "publisher": "Enke",
#     "year": "1978",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1978
#   },
#   {
#     "title": "Der vegetabile Patient und die Ethik der Medizin",
#     "authors": [
#       "Baruch A. Brody"
#     ],
#     "publisher": "Reclam",
#     "year": "1989",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1989
#   },
#   {
#     "title": "Medizin im NS-Staat",
#     "authors": [
#       "Wolfgang Benz"
#     ],
#     "publisher": "Dt. Taschenbuch-Verl.",
#     "year": "1993",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Die Bedeutung der Medizin",
#     "authors": [
#       "Thomas MacKeown"
#     ],
#     "publisher": "Suhrkamp",
#     "year": "1982",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "Bildverarbeitung f\u00fcr die Medizin: Grundlagen, Modelle, Methoden, Anwendungen",
#     "authors": [
#       "Thomas Martin Lehmann",
#       "Walter Oberschelp",
#       "Erich Pelikan",
#       "Rudolf Repges"
#     ],
#     "publisher": "Springer",
#     "year": "1997",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "Deskription und Analyse der in Deutschland existierenden Qualit\u00e4tssicherungs-Ma\u00dfnahmen in der Medizin.",
#     "authors": [
#       "B. Pietsch-Breitfeld",
#       "H. K. Selbmann"
#     ],
#     "publisher": "MMV Medizin Verlag",
#     "year": "1994",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "Computerunterst\u00fctzte Lehr- und Informationssysteme in der Medizin Instruktionspsychologische Grundlagen, Modelle und Anwendungen.",
#     "authors": [
#       "Detlev Leutner",
#       "B. Schultz-Br\u00fcnken",
#       "Roland Br\u00fcnken",
#       "Erich Pelikan",
#       "R. Kaminski",
#       "Helmut Buchner",
#       "Thomas Tolxdorff"
#     ],
#     "publisher": "MMV Medizin Verlag",
#     "year": "1996",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Teure Medizin",
#     "authors": [
#       "Gerhard Kocher",
#       "Pierre Rentchnick"
#     ],
#     "publisher": "Huber",
#     "year": "1980",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1980
#   },
#   {
#     "title": "Zur L\u00fcge verdammt? Politik, Medien, Medizin, Justiz, Wissenschaft und die Ethik der Wahrheit",
#     "authors": [
#       "Eberhard Schockenhoff"
#     ],
#     "publisher": "Herder",
#     "year": "2000",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Grunds\u00e4tze altindischer Medizin",
#     "authors": [
#       "Reinhold F. G. M\u00fcller"
#     ],
#     "publisher": "Ejnar Munksgaard",
#     "year": "1951",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1951
#   },
#   {
#     "title": "Industriearbeit und Medizin",
#     "authors": [
#       "Hans-Ulrich Deppe"
#     ],
#     "publisher": "Athen\u00e4um-Fischer-Taschenbuch-Verl.",
#     "year": "1973",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1973
#   },
#   {
#     "title": "Medizin und Nationalsozialismus",
#     "authors": [
#       "Gerhard Hrsg. Baader"
#     ],
#     "publisher": "Verl.-Ges. Gesundheit",
#     "year": "1980",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1980
#   },
#   {
#     "title": "Erstellung und Evaluation eines wissensbasierten Systems f\u00fcr die Durchf\u00fchrung von Projekten mit Neuronalen Netzen in der Medizin (HEAD).",
#     "authors": [
#       "M. N\u00f6hhmeier",
#       "Thomas Waschulzik",
#       "M. F\u00f6rster",
#       "F. Grothe",
#       "Wilfried Brauer",
#       "T. Sch\u00fctz",
#       "Rolf Engelbrecht"
#     ],
#     "publisher": "MMV Medizin Verlag",
#     "year": "1994",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "Technik, Medizin und Ethik. Praxis des Prinzips Verantwortung",
#     "authors": [
#       "Hans Jonas"
#     ],
#     "publisher": "Suhrkamp",
#     "year": "1996",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Eigenwertungen in altindischer Medizin",
#     "authors": [
#       "Reinhold F. G. M\u00fcller"
#     ],
#     "publisher": "Johann Ambrosius Barth",
#     "year": "1958",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1958
#   },
#   {
#     "title": "Expertensysteme in der Medizin",
#     "authors": [
#       "Frank Puppe"
#     ],
#     "publisher": "GIT Verlag",
#     "year": "1990",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Chipkarten in der Medizin.",
#     "authors": [
#       "Anja Hartmann"
#     ],
#     "publisher": "Springer",
#     "year": "1994",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "\u00dcber die tutorielle Nutzung medizinischer Diagnostik-Expertensysteme",
#     "authors": [
#       "Frank Puppe",
#       "Bernhard Puppe",
#       "Klaus Poeck"
#     ],
#     "publisher": "Gustav-Fischer-Verlag",
#     "year": "1993",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Medizin im \"Dritten Reich\"",
#     "authors": [
#       "Johanna Hrsg. Bleker",
#       "Gerhard Baader"
#     ],
#     "publisher": "Dt. \u00c4rzte-Verl.",
#     "year": "1993",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Schwerpunkt: Technik und Medizin",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Ed. Sigma",
#     "year": "1994",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "Internetbasierte Terminologiearbeit in der Medizin.",
#     "authors": [
#       "Stefanie Kethers",
#       "Bettina von Buol"
#     ],
#     "publisher": "CEUR-WS.org",
#     "year": "1996",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Medizin zwischen Kostend\u00e4mpfung und Fortschritt",
#     "authors": [
#       "Michael Arnold"
#     ],
#     "publisher": "Hirzel",
#     "year": "1986",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1986
#   },
#   {
#     "title": "Multimediale Systeme in der Medizin.",
#     "authors": [
#       "Peter Jensch"
#     ],
#     "publisher": "Springer",
#     "year": "1990",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Wissensbasierte Entscheidungsuntrst\u00fctzung in der Medizin.",
#     "authors": [
#       "Klaus-Peter Adlassnig"
#     ],
#     "publisher": "Springer",
#     "year": "1993",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Bildbebende Verfahren in der Medizin",
#     "authors": [
#       "Olaf D\u00f6ssel"
#     ],
#     "publisher": "Springer Verlag",
#     "year": "2000",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Cyclops - Wissensbasierte Bildanalyse in der Medizin.",
#     "authors": [
#       "Aldo von Wangenheim"
#     ],
#     "publisher": "Infix Verlag",
#     "year": "1997",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "Die soziale Dimension in der Medizin",
#     "authors": [
#       "Manfred Pflanz"
#     ],
#     "publisher": "Hippokrates",
#     "year": "1975",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1975
#   },
#   {
#     "title": "Anwendungen in Naturwissenschaften, Technik und Medizin",
#     "authors": [
#       "Karl Kurbel"
#     ],
#     "publisher": "Oldenbourg",
#     "year": "1993",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Manas und der Geist altindischer Medizin",
#     "authors": [
#       "Reinhold F. G. M\u00fcller"
#     ],
#     "publisher": "Johann Ambrosius Barth",
#     "year": "1952",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1952
#   },
#   {
#     "title": "Sinneslehre altindischer Medizin unter Beachtung arischer Grundlagen",
#     "authors": [
#       "Reinhold F. G. M\u00fcller"
#     ],
#     "publisher": "Kaiserlich Leopoldinisch-Carolinisch Deutsche Akademie der Naturforscher",
#     "year": "1944",
#     "type": "Publication",
#     "key": "medizin",
#     "year_correct": true,
#     "year_number": 1944
#   },
#   {
#     "title": "Zur Philosophie der Musik.",
#     "authors": [
#       "Ernst Bloch"
#     ],
#     "publisher": "Suhrkamp Verlag",
#     "year": "1974",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1974
#   },
#   {
#     "title": "\u00d6sterreichische Musik der Gegenwart. Elektronische Musik 1. 30 Jahre Elektroakustik",
#     "authors": [
#       "Anestis Logothetis"
#     ],
#     "publisher": "Amadeo Classic",
#     "year": "1988",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Mikrot\u00f6ne III: Bericht \u00fcber das 3. internationale Symposium \u201eMikrotonforschung, Musik mit Mikrot\u00f6nen, Ekmelische Musik``, 28.-30. April 1989 in Salzburg",
#     "authors": [
#       "Horst-Peter Hesse"
#     ],
#     "publisher": "Ed. Helbling",
#     "year": "1990",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "\u00d6sterreichische Musik der Gegenwart. Anestis Logothetis",
#     "authors": [
#       "Anestis Logothetis"
#     ],
#     "publisher": "Amadeo",
#     "year": "1985",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Gro\u00dfe Interpreten neuer Musik. Cage, Rush, Logothetis, Moran",
#     "authors": [
#       "Anestis Logothetis"
#     ],
#     "publisher": "Wergo",
#     "year": "1971",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1971
#   },
#   {
#     "title": "Konzertante Musik des 20. Jahrhunderts",
#     "authors": [
#       "Anestis Logothetis"
#     ],
#     "publisher": "Proviva",
#     "year": "1990",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Extensionale Standardsprache der Musiktheorie : eine Schnittstelle zwischen Musik und Informatik",
#     "authors": [
#       "Wilfried Neumaier",
#       "Rudolf Wille"
#     ],
#     "publisher": "FachbereichMathemetik. Technische Hochschule Darmstadt",
#     "year": "1988",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Mikrot\u00f6ne II : Bericht \u00fcber das 2. Internationale Symposium \"Mikrotonforschung, Musik mit Mikrot\u00f6nen, Ekmelische Musik\", 22.-24. Mai 1987 in Salzburg",
#     "authors": [
#       "Franz Richter Herf"
#     ],
#     "publisher": "Ed. Helbling",
#     "year": "1988",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Werbung mit Musik",
#     "authors": [
#       "J\u00fcrgen Tauchnitz"
#     ],
#     "publisher": "Physica-Verl.",
#     "year": "1990",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Frauen und Musik",
#     "authors": [
#       "Yves Bessi\u00e8res",
#       "Patricia Niedzwiecki"
#     ],
#     "publisher": "Komm. der Europ. Gemeinschaften, Generaldirektion Information",
#     "year": "1985",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Musik und Rhythmus bei den Griechen: zum Ursprung der abendl\u00e4ndischen Musik",
#     "authors": [
#       "Thrasybulos G. Georgiades"
#     ],
#     "publisher": "Rowohlt",
#     "year": "1958",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1958
#   },
#   {
#     "title": "AUF WOHLKLANGSWELLEN DURCH DER T\u00d6NE MEER",
#     "authors": [
#       "Klaus Lang"
#     ],
#     "publisher": "Institut f\u00fcr Elektronische Musik (IEM) an der Universit\u00e4t f\u00fcr Musik und darstellende Kunst in Graz",
#     "year": "1999",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "Mitteilungen des \u00d6KB. Neue Musik am Bruckner-Konservatorium Linz",
#     "authors": [
#       "Anton Voigt"
#     ],
#     "publisher": "B\u00f6hlau",
#     "year": "1990",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Musik als Trinit\u00e4tssymbol : Einf\u00fchrung in die harmonikale Metaphysik",
#     "authors": [
#       "Erwin Schadel"
#     ],
#     "publisher": "Lang",
#     "year": "1995",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "Gruppen und Ketegorien in der Musik -- Entwurf einre mathematischen Musiktheorie",
#     "authors": [
#       "Guerino Mazzola"
#     ],
#     "publisher": "Heldermann Verlag",
#     "year": "1985",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Popul\u00e4re Musik und P\u00e4dagogik. Orale Musiktradierung, Musiktheorie, Improvisation, mediale Lebenswelten.",
#     "authors": [
#       "J\u00fcrgen Terhag"
#     ],
#     "publisher": "Lugert Verlag",
#     "year": "2000",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Neue Schallplatten mit zeitgen\u00f6ssischer \u00f6sterreichischer Musik",
#     "authors": [
#       "Walter Szmolyan"
#     ],
#     "publisher": "B\u00f6hlau",
#     "year": "1986",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1986
#   },
#   {
#     "title": "Die Lehre von den Tonempfindungen als Physiologische Grundlage f\u00fcr die Theorie der Musik",
#     "authors": [
#       "H. Helmholtz"
#     ],
#     "publisher": "Vieweg",
#     "year": "1863",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1863
#   },
#   {
#     "title": "Harmoniesystem in dualer Entwicklung",
#     "authors": [
#       "Dr. Arthur von Oettingen"
#     ],
#     "publisher": "W. Gl\u00e4ser",
#     "year": "1866",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1866
#   },
#   {
#     "title": "Popul\u00e4re Darstellung der Akustik in Beziehung zur Musik...Im Anschluss an Hermann von Helmholtz' \"Lehre von den Tonempfindungen\"...",
#     "authors": [
#       "Ludwig. Riemann"
#     ],
#     "publisher": "Braunschweig: F. Vieweg & Sohn,",
#     "year": "1896",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1896
#   },
#   {
#     "title": "Introduction to Neo-Riemannian Theory: A Survey and a Historical Perspective",
#     "authors": [
#       "Richard Cohn"
#     ],
#     "publisher": "Duke University Press on behalf of the Yale University Department of Music",
#     "year": "1998",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Aus welchem Material ist der Stein von Sisyphos!?, ein multimediales B\u00fchnenwerk",
#     "authors": [
#       "Anestis Logothetis"
#     ],
#     "publisher": "Gesellschaft zur F\u00f6rderung \u00d6sterreichischer Musik",
#     "year": "1995",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "Some Mathematical Aspects of David Lewin's Book: Generalized Musical Intervals and Transformations",
#     "authors": [
#       "Dan Tudor Vuza"
#     ],
#     "publisher": "Perspectives of New Music",
#     "year": "1988",
#     "type": "Publication",
#     "key": "musik",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "A  \u201d Schr\u00f6dinger Cat\u201d Superposition State of an Atom",
#     "authors": [
#       "C. Monroe",
#       "D. M. Meekhof",
#       "B. E. King",
#       "D. J. Wineland"
#     ],
#     "publisher": "American Association for the Advancement of Science",
#     "year": "1996",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "M\u00e9thodologie de la balance des paiements de la France",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Amt f\u00fcr Amtliche Ver\u00f6ff. der Europ. Gemeinschaften",
#     "year": "1984",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1984
#   },
#   {
#     "title": "The methodology of Ireland's balance of payments",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Office for Official Publ. of the Europ. Communities",
#     "year": "1980",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1980
#   },
#   {
#     "title": "La m\u00e9thodologie de la balance des paiements de l'Union \u00e9conomique belgo-luxembourgeoise",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Office des publications officielles des Communaut\u00e9es europ\u00e9ennes",
#     "year": "1985",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Cat\u00e9gories et structures",
#     "authors": [
#       "Charles Ehresmann"
#     ],
#     "publisher": "Dunod",
#     "year": "1965",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1965
#   },
#   {
#     "title": "Physiology and topography of neurons with multipeaked tuning curves in cat primary auditory cortex",
#     "authors": [
#       "ML Sutter",
#       "CE Schreiner"
#     ],
#     "publisher": "Am Physiological Soc",
#     "year": "1991",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1991
#   },
#   {
#     "title": "Highlights of CMU Research on CAD, CAM, CAT of VLSI Circuits.",
#     "authors": [
#       "John Paul Shen"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1986",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1986
#   },
#   {
#     "title": "Vocational training staff in Italy",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Office for Official Publ. of the Europ. Communities",
#     "year": "1984",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1984
#   },
#   {
#     "title": "Intervention and efficiency",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Canadian Gov. Publ. Centre",
#     "year": "1982",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "The Type Structure of CAT.",
#     "authors": [
#       "J. Paul Myers Jr.",
#       "Ronald E. Prather"
#     ],
#     "publisher": "Springer",
#     "year": "1991",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1991
#   },
#   {
#     "title": "La production du raisin",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Office des Publ. Officielles des Communaut\u00e9s Europ\u00e9nnes",
#     "year": "1985",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Le Langage des cat\u00e9gories",
#     "authors": [
#       "Peter J. Hilton",
#       "J. C. Matthys",
#       " Papy"
#     ],
#     "publisher": "CEDIC",
#     "year": "1973",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1973
#   },
#   {
#     "title": "My Cat is Object-Oriented",
#     "authors": [
#       "R. King"
#     ],
#     "publisher": "ACM Press",
#     "year": "1989",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1989
#   },
#   {
#     "title": "Les co\u00fbts des production du vin de table en Espagne, France et Italie",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Office des Publ. Officielles des Communaut\u00e9s Europ\u00e9nnes",
#     "year": "1985",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "My Cat Is Object-Oriented.",
#     "authors": [
#       "Roger King"
#     ],
#     "publisher": "ACM Press and Addison-Wesley",
#     "year": "1989",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1989
#   },
#   {
#     "title": "EG-W\u00f6rterverzeichnis",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Office des Publ. Officielles des Communaut\u00e9s Europ\u00e9ennes",
#     "year": "1982",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "Work sharing and the reduction and reorganisation of working time at firm level",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Office for Official Publ. of the Europ. Communities",
#     "year": "1985",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Labour market development in the 1980s",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Minister of Supply and Services Canada",
#     "year": "1981",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1981
#   },
#   {
#     "title": "In short supply",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "Canadian Government Publ. Centre",
#     "year": "1982",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "CAD/CAM f\u00fcr mittelst\u00e4ndische Unternehmen",
#     "authors": [
#       "Siegfried Schreuder",
#       "Norbert Fuest"
#     ],
#     "publisher": "Verl. T\u00dcV Rheinland",
#     "year": "1988",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "CAT: The Copying Approach to Tabling.",
#     "authors": [
#       "Bart Demoen",
#       "Konstantinos Sagonas"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Inventory management simulations at Cat Logistics.",
#     "authors": [
#       "C. Ann Goodsell",
#       "Thomas J. Van Kley"
#     ],
#     "publisher": "WSC",
#     "year": "2000",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "The cat in the hat text",
#     "authors": [
#       "Dr. Seuss"
#     ],
#     "publisher": "Houghton Mifflin",
#     "year": "1957",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1957
#   },
#   {
#     "title": "CAD-CAE-CAM-CIM-Lexikon",
#     "authors": [
#       "Gerhard Klause"
#     ],
#     "publisher": "Expert-Verl. u.a.",
#     "year": "1987",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1987
#   },
#   {
#     "title": "CAT Finland: Executing Primitive Tasks in Parallel.",
#     "authors": [
#       "Jukka Riekki",
#       "Jussi Pajala",
#       "Antti Tikanm\u00e4ki",
#       "Juha R\u00f6ning"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Die formale Entwicklung der maschinenunabh\u00e4ngigen Zwischensprache CAT.",
#     "authors": [
#       "Uwe Schmidt",
#       "Reinhard V\u00f6ller"
#     ],
#     "publisher": "Springer",
#     "year": "1981",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1981
#   },
#   {
#     "title": "A Specification of the Cat and Mouse Problem.",
#     "authors": [
#       "William G. Wood"
#     ],
#     "publisher": "Springer",
#     "year": "1991",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1991
#   },
#   {
#     "title": "An overview of the AMC WWMCCS CAT Guard.",
#     "authors": [
#       "Ricki Andrew Vick"
#     ],
#     "publisher": "IEEE",
#     "year": "1992",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "Cortio-Tectal Interactions in the Cat Visual System.",
#     "authors": [
#       "Michael Brecht",
#       "Andreas K. Engel"
#     ],
#     "publisher": "Springer",
#     "year": "1996",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "An overview of CAT control in nuclear services.",
#     "authors": [
#       "Gilles Clement",
#       "J. Vertut",
#       "Raymond Fournier",
#       "Bernard Espiau",
#       "G. Andr\u00e9"
#     ],
#     "publisher": "IEEE",
#     "year": "1985",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Temporal Integration and Duration Tuning in the Dorsal Zone of Cat Auditory Cortex",
#     "authors": [
#       "J. He",
#       "T. Hashikawa",
#       "H. Ojima",
#       "Y. Kinouchi"
#     ],
#     "publisher": "Soc Neuroscience",
#     "year": "1997",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "CAT: An Execution Model for Concurrent Full Text Search.",
#     "authors": [
#       "Zheng Lin"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1991",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1991
#   },
#   {
#     "title": "CEDS TO GROW A CAT: A Progress/Studio Report.",
#     "authors": [
#       "Noel Zahler"
#     ],
#     "publisher": "Michigan Publishing",
#     "year": "1991",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1991
#   },
#   {
#     "title": "Context-Dependent Excitation Bandwidth Changes in Cat Auditory Cortex.",
#     "authors": [
#       "Christoph E. Schreiner",
#       "Sarah W. Wong"
#     ],
#     "publisher": "IOA Press",
#     "year": "1998",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "A Mathematical Model for the CAT Framwork of EUROTRA.",
#     "authors": [
#       "Theo M. V. Janssen"
#     ],
#     "publisher": "Springer",
#     "year": "1988",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Geometric Relationships Between Feature Maps in Cat Visual Cortex.",
#     "authors": [
#       "Mark H\u00fcbener",
#       "Doron Shoham",
#       "S. Schulze",
#       "G. Br\u00e4ndle",
#       "Amiram Grinvald",
#       "Tobias Bonhoeffer"
#     ],
#     "publisher": "Springer",
#     "year": "1997",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "Computer aided technologies",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "M\u00fcller adress + Neue Mediengesellschaft Ulm",
#     "year": "1993",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "ARC: An Extended ATMS Based on Directed CAT-Correct Resolution.",
#     "authors": [
#       "Pierre Tayrac"
#     ],
#     "publisher": "Springer",
#     "year": "1990",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Glossar CAD/CAM",
#     "authors": [
#       "R\u00fcdiger Lange",
#       "G\u00fcnter Watzlawik"
#     ],
#     "publisher": "Siemens-Aktienges.",
#     "year": "1987",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1987
#   },
#   {
#     "title": "Organization of Inhibitory Frequency Receptive Fields in Cat Primary Auditory Cortex",
#     "authors": [
#       "ML Sutter",
#       "CE Schreiner",
#       "M. McLean",
#       "KN O'connor",
#       "WC Loftus"
#     ],
#     "publisher": "Am Physiological Soc",
#     "year": "1999",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "EE-CAT: extended electronic catalog for dynamic and flexible electronic commerce.",
#     "authors": [
#       "Jihye Jung",
#       "Dongkyu Kim",
#       "Sang goo Lee",
#       "Chisu Wu",
#       "Kapsoo Kim"
#     ],
#     "publisher": "IDEA Group Publishing",
#     "year": "2000",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Barbara Hannah: The Cat, Dog, and Horse Lectures, and the Beyond",
#     "authors": [
#       "Barbara Hannah"
#     ],
#     "publisher": "Chiron",
#     "year": "1992",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "Physiological studies on neurons in the dorsal cochlear nucleus of cat",
#     "authors": [
#       "WS Rhode",
#       "PH Smith"
#     ],
#     "publisher": "Am Physiological Soc",
#     "year": "1986",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1986
#   },
#   {
#     "title": "CAT: A High Performance Distributed Component Architecture Toolkit for the Grid.",
#     "authors": [
#       "Juan E. Villacis",
#       "Madhusudhan Govindaraju",
#       "David Stern",
#       "Andrew Whitaker",
#       "Fabian Breg",
#       "Prafulla Deuskar",
#       "Benjamin Temko",
#       "Dennis Gannon",
#       "Randall Bramley"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1999",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "Functional topography of cat primary auditory cortex: distribution of integrated excitation",
#     "authors": [
#       "CE Schreiner",
#       "JR Mendelson"
#     ],
#     "publisher": "Am Physiological Soc",
#     "year": "1990",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Proceedings 13th Brazilian Symposium on Computer Graphics and Image Processing (Cat. No.PR00878).",
#     "authors": [
#       "Laurence Tianruo Yang"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "2000",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "The Receptive Field Structure of Retinal Ganglion Cells in Cat and Monkey",
#     "authors": [
#       "Ehud Kaplan"
#     ],
#     "publisher": "CRC Press",
#     "year": "1989",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1989
#   },
#   {
#     "title": "The platform of corporate development and management CAT software on the Web.",
#     "authors": [
#       "Jia Zhuosheng",
#       "Wei Huoqing"
#     ],
#     "publisher": "AACE",
#     "year": "1996",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "CAD-CAM-Planung langfristiger Gesamtkonzeptionen",
#     "authors": [
#       "Helmut Sch\u00e4fer"
#     ],
#     "publisher": "VDI-Verl.",
#     "year": "1990",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Functional Structures from Different Components of Intrinsic Signal in Cat Visual Cortex.",
#     "authors": [
#       "Mitsuhiro Fukuda",
#       "Makoto Nishizaki",
#       "Manabu Tanifuji"
#     ],
#     "publisher": "IOA Press",
#     "year": "1998",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Rationalisierung durch CAD/CAQ-Systeme",
#     "authors": [
#       "Horst Schwarz",
#       "Walter Steinbach"
#     ],
#     "publisher": "VWP, Verl. Wissen u. Praxis",
#     "year": "1989",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1989
#   },
#   {
#     "title": "Cat\ufffdlogo expediciones y viajes cient\ufffdficos espa\ufffdoles a Am\ufffdrica",
#     "authors": [
#       "Mar\ufffda de los Angeles Calatayud Arinero"
#     ],
#     "publisher": "CSIC",
#     "year": "1984",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1984
#   },
#   {
#     "title": "CAD - CAM, Entscheidungshilfen f\u00fcr das Management",
#     "authors": [
#       "Willi Poths",
#       "Rudolf L\u00f6w"
#     ],
#     "publisher": "H\u00fcthig",
#     "year": "1989",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1989
#   },
#   {
#     "title": "Visual Cortex Neurons in Monkey and Cat: Contrast Response Nonlinearities and Stimulus Selectivity",
#     "authors": [
#       "D. G. Albrecht",
#       "W. S. Geisler"
#     ],
#     "publisher": "SPIE",
#     "year": "1994",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "Are you my little pussy-cat? acoustic, phonetic and affective qualities of infant- and pet-directed speech.",
#     "authors": [
#       "Denis Burnham",
#       "Elizabeth Francis",
#       "Ute Vollmer-Conna",
#       "Christine Kitamura",
#       "Vicky Averkiou",
#       "Amanda Olley",
#       "Mary Nguyen",
#       "Cal Paterson"
#     ],
#     "publisher": "ISCA",
#     "year": "1998",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "OWL-Cat: A Web-Based OPAC Appealing End-Users to Exploit Library Resources.",
#     "authors": [
#       "Silvana Mangiaracina",
#       "Stefano Ferrarini",
#       "Maria Grazia Balestri"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Processing of Complex Sounds in the Auditory Cortex of Cat, Monkey, and Man",
#     "authors": [
#       "JP Rauschecker"
#     ],
#     "publisher": "Informa Healthcare",
#     "year": "1997",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "Organisations- und Qualifizierungskonzepte bei CAD/CAM-Einf\u00fchrung",
#     "authors": [
#       "Werner Knetsch"
#     ],
#     "publisher": "E. Schmidt",
#     "year": "1987",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1987
#   },
#   {
#     "title": "Cat-a-Cone: An Interactive Interface for Specifying Searches and Viewing Retrieval Results using a Large Category Hierarchy.",
#     "authors": [
#       "Marti A. Hearst",
#       "Chandu Karadi"
#     ],
#     "publisher": "ACM",
#     "year": "1997",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "Low level modeling of the development of directionally selective microcircuits in cat striate cortex.",
#     "authors": [
#       "Andrew H. Fagg",
#       "J\u00f3zsef Fiser"
#     ],
#     "publisher": "IEEE",
#     "year": "1993",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Cat\ufffdlogo de documentos de la secci\ufffdn novena del Archivo General de Indias",
#     "authors": [
#       "Cristobal Berm\ufffddez Plata"
#     ],
#     "publisher": "Escuela de Estudios Hispanoamericanos",
#     "year": "1949",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1949
#   },
#   {
#     "title": "Comment les robots construisent leur monde : Experiences sur la convergence des cat\u00e9gories sensorielles",
#     "authors": [
#       "F. Kaplan",
#       "L. Steels"
#     ],
#     "publisher": "ENST Paris, ENST 2000-S-004",
#     "year": "2000",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "CAT - Caching Address Tags: A Technique for Reducing Area Cost of On-Chip Caches.",
#     "authors": [
#       "Hong Wang",
#       "Tong Sun",
#       "Qing Yang"
#     ],
#     "publisher": "ACM",
#     "year": "1995",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "Object-Oriented Specification on LOTOS and Z, or My Cat Really is Object-Oriented!",
#     "authors": [
#       "Elspeth Cusack",
#       "Michael Lai"
#     ],
#     "publisher": "Springer",
#     "year": "1990",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Dual Inhibitory Mechanisms for Definition of Receptive Field Characteristics in a Cat Striate Cortex.",
#     "authors": [
#       "A. B. Bonds"
#     ],
#     "publisher": "Morgan Kaufmann",
#     "year": "1991",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1991
#   },
#   {
#     "title": "InterCAD - Internet-basierte Dienstleistungen f\u00fcr CAD/CAM-Anwender aus der Zulieferindustrie.",
#     "authors": [
#       "Uwe Schwabe"
#     ],
#     "publisher": "GI",
#     "year": "2000",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Topography of excitatory bandwidth in cat primary auditory cortex: single-neuron versus multiple-neuron recordings",
#     "authors": [
#       "CE Schreiner",
#       "ML Sutter"
#     ],
#     "publisher": "Am Physiological Soc",
#     "year": "1992",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "A guide to current sources of wage statistics in the European community",
#     "authors": [
#       "David Marsden",
#       "Lydia Redlbacher"
#     ],
#     "publisher": "Off. for Off. Publ. of the Europ. Communities",
#     "year": "1984",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1984
#   },
#   {
#     "title": "Multiple job holders",
#     "authors": [
#       "Jeremy Alden",
#       "Richard Spooner"
#     ],
#     "publisher": "Off. for Off. Publ. of the Europ. Communities",
#     "year": "1982",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "CAD/CAM Einsatz in Entwurf, Konstruktion und Fertigung von Flugzeugen.",
#     "authors": [
#       "L. Thieme"
#     ],
#     "publisher": "Springer",
#     "year": "1980",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1980
#   },
#   {
#     "title": "Population Coding in Cat Visual Cortex Reveals Nonlinear Interactions as Predicted by a Neural Field Model.",
#     "authors": [
#       "Dirk Jancke",
#       "Amir C. Akhavan",
#       "Wolfram Erlhagen",
#       "Martin A. Giese",
#       "Axel Steinhage",
#       "Gregor Sch\u00f6ner",
#       "Hubert R. Dinse"
#     ],
#     "publisher": "Springer",
#     "year": "1996",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "The CAT-exact data transfer to DDS-generated clock domains in a single-chip modular solution.",
#     "authors": [
#       "Robert Gage",
#       "Ben Brown"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1998",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "CAD/CAM-Einbindung in die betriebliche Informationsumgebung",
#     "authors": [
#       " ?"
#     ],
#     "publisher": "CW-Publ. Verl.Ges.",
#     "year": "1985",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "The effects of control node density in cellular network planning using the combination algorithm for total optimisation (CAT).",
#     "authors": [
#       "Araceli Molina",
#       "Andrew R. Nix",
#       "Georgia E. Athanasiadou"
#     ],
#     "publisher": "IEEE",
#     "year": "2000",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Verarbeitung geometrischer Informationen in einer CAD/CAP-integrierten Umgebung.",
#     "authors": [
#       "J. Xu",
#       "W. Ma\u00dfberg"
#     ],
#     "publisher": "Springer",
#     "year": "1992",
#     "type": "Publication",
#     "key": "cat",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "Die Kunst, Recht zu behalten: In achtunddrei\u00dfig Kunstgriffen dargestellt",
#     "authors": [
#       "Arthur Schopenhauer"
#     ],
#     "publisher": "Insel, Frankfurt",
#     "year": "1995",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "Griechische Kunst",
#     "authors": [
#       "John Boardman"
#     ],
#     "publisher": "Hatje",
#     "year": "1988",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Fr\u00fchgriechische Kunst: Kunst und Siedlung im geometrischen Griechenland",
#     "authors": [
#       "Wolf-Dieter Heilmeyer"
#     ],
#     "publisher": "Gebr. Mann",
#     "year": "1982",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "\u00d6konomie und Kunst",
#     "authors": [
#       "Georg Krieger"
#     ],
#     "publisher": "Duncker & Humblot",
#     "year": "1996",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Kunst kontra \u00c4sthetik",
#     "authors": [
#       "Antoni T\u00e0pies"
#     ],
#     "publisher": "Erker",
#     "year": "1983",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1983
#   },
#   {
#     "title": "Kunst-Psychologie - Wodurch Kunstwerke wirken",
#     "authors": [
#       "Martin Schuster",
#       "Horst Beisl",
#       "Manfred Hahn"
#     ],
#     "publisher": "DuMont",
#     "year": "1978",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1978
#   },
#   {
#     "title": "Kunst des Handelns",
#     "authors": [
#       "Michel de Certeau"
#     ],
#     "publisher": "Merve-Verlag",
#     "year": "1988",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Was ist r\u00f6mische Kunst?",
#     "authors": [
#       "Otto J. Brendel"
#     ],
#     "publisher": "DuMont",
#     "year": "1990",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Kleine Geschichte der chinesischen Kunst",
#     "authors": [
#       "Anita Rolf"
#     ],
#     "publisher": "DuMont",
#     "year": "1985",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1985
#   },
#   {
#     "title": "Staatliche Sammlung \u00c4gyptischer Kunst M\u00fcnchen",
#     "authors": [
#       "Sylvia Schoske",
#       "Dietrich Wildung"
#     ],
#     "publisher": "Zabern",
#     "year": "1995",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "Lethe. Kunst und Kritik des Vergessens",
#     "authors": [
#       "Harald Weinrich"
#     ],
#     "publisher": "C.H. Beck",
#     "year": "2000",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Die volkswirtschaftliche Bedeutung von Kunst und Kultur",
#     "authors": [
#       "Marlies Hummel",
#       "Manfred Berger"
#     ],
#     "publisher": "Duncker & Humblot",
#     "year": "1988",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1988
#   },
#   {
#     "title": "Das Museum f\u00fcr Sp\u00e4tantike und Byzantinische Kunst",
#     "authors": [
#       "Arne Effenberger"
#     ],
#     "publisher": "von Zabern",
#     "year": "1992",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "Kreta: Von den Anf\u00e4ngen Europas bis zur kreto-venezianischen Kunst",
#     "authors": [
#       "Klaus Gallas"
#     ],
#     "publisher": "DuMont",
#     "year": "1990",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1990
#   },
#   {
#     "title": "Kunst und Charisma. Gedanken zum Werk Joannis Avramidis",
#     "authors": [
#       "Ulrich Oevermann"
#     ],
#     "publisher": "Galerie Appel und Fertsch",
#     "year": "1986",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1986
#   },
#   {
#     "title": "Kunst im 20. Jahrhundert: Moderne - Postmoderne - Zweite Moderne",
#     "authors": [
#       "Heinrich Klotz"
#     ],
#     "publisher": "Beck",
#     "year": "1994",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "Kunst und Illusion : zur Psychologie der bildlichen Darstellung",
#     "authors": [
#       "Ernst H. Gombrich"
#     ],
#     "publisher": "Belser",
#     "year": "1978",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1978
#   },
#   {
#     "title": "Kunst und Sehen:  eine Psychologie des sch\u00f6pferischen Auges",
#     "authors": [
#       "Rudolf Arnheim"
#     ],
#     "publisher": "de Gruyter",
#     "year": "1978",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1978
#   },
#   {
#     "title": "Die Besteuerung der Kunst",
#     "authors": [
#       "Carl-Heinz Heuer"
#     ],
#     "publisher": "Deubner",
#     "year": "1983",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1983
#   },
#   {
#     "title": "Die Kunst des alten Mesopotamien, Bd. 1: Sumer und Akkad",
#     "authors": [
#       "Anton Moortgat"
#     ],
#     "publisher": "DuMont",
#     "year": "1982",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "Die Kunst des alten Mesopotamien, Bd. 2: Babylon und Assur",
#     "authors": [
#       "Anton Moortgat"
#     ],
#     "publisher": "DuMont",
#     "year": "1984",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1984
#   },
#   {
#     "title": "Natur und Design: Inspirationen f\u00fcr Architektur, Mode und angewandte Kunst",
#     "authors": [
#       "Alan Powers"
#     ],
#     "publisher": "Haupt",
#     "year": "2000",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Ornament und Kunst : Schmucktrieb und Ordnungssinn in der Psychologie des dekorativen Schaffens",
#     "authors": [
#       "Ernst H. Gombrich"
#     ],
#     "publisher": "Klett-Cotta",
#     "year": "1982",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1982
#   },
#   {
#     "title": "Die r\u00f6mische Kunst: Von den Anf\u00e4ngen bis zum Ende der Antike",
#     "authors": [
#       "Ranuccio Bianchi Bandinelli"
#     ],
#     "publisher": "Beck",
#     "year": "1975",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1975
#   },
#   {
#     "title": "DADA - Kunst und Antikunst",
#     "authors": [
#       "Hans Richter"
#     ],
#     "publisher": "Dumont",
#     "year": "1978",
#     "type": "Publication",
#     "key": "kunst",
#     "year_correct": true,
#     "year_number": 1978
#   },
#   {
# ...
#     "authors": [
#       "Moni Naor",
#       "Avishai Wool"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1994",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "Evaluating Quorum Systems over the Internet.",
#     "authors": [
#       "Yair Amir",
#       "Avishai Wool"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1996",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Crumbling Walls: A Class of Practical and Efficient Quorum Systems (Extended Abstract).",
#     "authors": [
#       "David Peleg",
#       "Avishai Wool"
#     ],
#     "publisher": "ACM",
#     "year": "1995",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "How to Prove Where You Are: Tracking the Location of Customer Equipment.",
#     "authors": [
#       "Eran Gabber",
#       "Avishai Wool"
#     ],
#     "publisher": "ACM",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Evaluating Quorum Systems Over the Internet (Abstract).",
#     "authors": [
#       "Yair Amir",
#       "Avishai Wool"
#     ],
#     "publisher": "ACM",
#     "year": "1996",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Quorum-Based Secure Multi-party Computation.",
#     "authors": [
#       "Donald Beaver",
#       "Avishai Wool"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "A wool specification expert system in LEVEL 5 ObjectTM or experiences of a procedural programmer with a hybrid system.",
#     "authors": [
#       "D. C. Maddever"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1995",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "Fuels from wood waste",
#     "authors": [
#       "F. Shafizadeh"
#     ],
#     "publisher": "Fuels from waste.~(A78-27801 10-44) New York, Academic Press, Inc., 1977, p.~141-159.",
#     "year": "1977",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1977
#   },
#   {
#     "title": "Approximating Bounded 0-1 Integer Linear Programs.",
#     "authors": [
#       "David Peleg",
#       "Gideon Schechtman",
#       "Avishai Wool"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1993",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Towards Making Broadcast Encryption Practical.",
#     "authors": [
#       "Michel Abdalla",
#       "Yuval Shavitt",
#       "Avishai Wool"
#     ],
#     "publisher": "Springer",
#     "year": "1999",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "Fang: A Firewall Analysis Engine.",
#     "authors": [
#       "Alain J. Mayer",
#       "Avishai Wool",
#       "Elisha Ziskind"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "The Load and Availability of Byzantine Quorum Systems.",
#     "authors": [
#       "Dahlia Malkhi",
#       "Michael K. Reiter",
#       "Avishai Wool"
#     ],
#     "publisher": "ACM",
#     "year": "1997",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "Long-Lived Broadcast Encryption.",
#     "authors": [
#       "Juan A. Garay",
#       "Jessica Staddon",
#       "Avishai Wool"
#     ],
#     "publisher": "Springer",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Optimal Layouts on a Chain ATM Network (Extended Abstract).",
#     "authors": [
#       "Ornan Ori Gerstel",
#       "Avishai Wool",
#       "Shmuel Zaks"
#     ],
#     "publisher": "Springer",
#     "year": "1995",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1995
#   },
#   {
#     "title": "Theory of Computation",
#     "authors": [
#       "D. Wood"
#     ],
#     "publisher": "Harper and Row, New York",
#     "year": "1987",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1987
#   },
#   {
#     "title": "Econometric models of world agricultural commodity markets",
#     "authors": [
#       "Francis G. Adams",
#       "Jere R. Behrman"
#     ],
#     "publisher": "Ballinger",
#     "year": "1976",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1976
#   },
#   {
#     "title": "Firmato: A Novel Firewall Management Toolkit.",
#     "authors": [
#       "Yair Bartal",
#       "Alain J. Mayer",
#       "Kobbi Nissim",
#       "Avishai Wool"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1999",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "Replication, Consistency, and Practicality: Are These Mutually Exclusive?",
#     "authors": [
#       "Todd A. Anderson",
#       "Yuri Breitbart",
#       "Henry F. Korth",
#       "Avishai Wool"
#     ],
#     "publisher": "ACM Press",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Probabilistic Byzantine Quorum Systems.",
#     "authors": [
#       "Dahlia Malkhi",
#       "Michael K. Reiter",
#       "Avishai Wool",
#       "Rebecca N. Wright"
#     ],
#     "publisher": "ACM",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Data structures, algorithms, and performance",
#     "authors": [
#       "Derick Wood"
#     ],
#     "publisher": "Addison-Wesley",
#     "year": "1993",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "WIA and Theory and Practice.",
#     "authors": [
#       "Derick Wood"
#     ],
#     "publisher": "Springer",
#     "year": "1997",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "How a visualization tool can be used: Evaluating a tool in a research & development project.",
#     "authors": [
#       "Matti Lattu",
#       "Jorma Tarhio",
#       "Veijo Meisalo"
#     ],
#     "publisher": "Psychology of Programming Interest Group",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Tabular Formatting Problems.",
#     "authors": [
#       "Xinxin Wang",
#       "Derick Wood"
#     ],
#     "publisher": "Springer",
#     "year": "1996",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "SGML and Exceptions.",
#     "authors": [
#       "Pekka Kilpel\u00e4inen",
#       "Derick Wood"
#     ],
#     "publisher": "Springer",
#     "year": "1996",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "SGML and Exceptions",
#     "authors": [
#       "Pekka Kilpel\u00e4inen",
#       "Derick Wood"
#     ],
#     "publisher": "Springer-Verlag",
#     "year": "1996",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "Wettbewerbsorientierte Stromversorgung im Pool-System",
#     "authors": [
#       "Kristina K\u00f6ster"
#     ],
#     "publisher": "Nomos-Verl.-Ges.",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "A new DNA separation technique with a low error rate.",
#     "authors": [
#       "Junghuei Chen",
#       "David Harlan Wood"
#     ],
#     "publisher": "DIMACS/AMS",
#     "year": "1997",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1997
#   },
#   {
#     "title": "A DNA Implementation of the Max 1s Problem",
#     "authors": [
#       "David Wood",
#       "Junghuei Chen",
#       "Eugene Antipov Bertrand Lemieux",
#       "Walter Cedeno"
#     ],
#     "publisher": "Morgan Kaufmann",
#     "year": "1999",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "\u00dcbungsbuch zur allgemeinen Volkswirtschaftslehre",
#     "authors": [
#       "Artur Woll",
#       "Hans J\u00f6rg Thieme",
#       "Dieter Cassel"
#     ],
#     "publisher": "Vahlen",
#     "year": "1974",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1974
#   },
#   {
#     "title": "Computed Web Links: The COOL Link Model",
#     "authors": [
#       "Michael Miller",
#       "L. Jay Wantz"
#     ],
#     "publisher": "Kluwer Academic Publishers",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Three Guineas",
#     "authors": [
#       "Virginia Woolf"
#     ],
#     "publisher": "Harcourt, Brace",
#     "year": "1966",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1966
#   },
#   {
#     "title": "A Configuration Tool to Increase Product Competitiveness",
#     "authors": [
#       "Bei Yu",
#       "Hans J\u00f8rgen Skovgaard"
#     ],
#     "publisher": "IEEE Educational Activities Department",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "A Conceptual Model for Tables.",
#     "authors": [
#       "Xinxin Wang",
#       "Derick Wood"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "A visual language for a sketch-based UI prototyping tool",
#     "authors": [
#       "James Lin"
#     ],
#     "publisher": "ACM",
#     "year": "1999",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "Instruction Computation in Subset Construction.",
#     "authors": [
#       "J. Howard Johnson",
#       "Derick Wood"
#     ],
#     "publisher": "Springer",
#     "year": "1996",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "A cognitive interactive dimension analysis tool.",
#     "authors": [
#       "Chris Roast",
#       "Jawed Siddiqi"
#     ],
#     "publisher": "Psychology of Programming Interest Group",
#     "year": "1999",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1999
#   },
#   {
#     "title": "A debate on language and tool support for design patterns",
#     "authors": [
#       "Craig Chambers",
#       "Bill Harrison",
#       "John Vlissides"
#     ],
#     "publisher": "ACM",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Metric 3D Surface Reconstruction from Uncalibrated Image Sequences.",
#     "authors": [
#       "Marc Pollefeys",
#       "Reinhard Koch",
#       "Maarten Vergauwen",
#       "Luc Van Gool"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Development of fuzzy neural tool for medical signal processing and imaging.",
#     "authors": [
#       "Woon-Seng Gan"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1992",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "What Next? The Intellectual Legacy of Ithiel de Sola Pool",
#     "authors": [
#       "Lloyd S. Etheredge"
#     ],
#     "publisher": "Transaction",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Improvement of congestion control for burst traffic.",
#     "authors": [
#       "Hyoung-Woo Park",
#       "Jin-Wook Chung"
#     ],
#     "publisher": "CSREA Press",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Middleware for realtime multicomputer tool development.",
#     "authors": [
#       "Barry Isenstein",
#       "Michael Krueger",
#       "Arlan Pool"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1996",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1996
#   },
#   {
#     "title": "A Compact Model for Viewpoint Dependent Texture Synthesis.",
#     "authors": [
#       "Alexey Zalesny",
#       "Luc Van Gool"
#     ],
#     "publisher": "Springer",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "CUMULI, PANORAMA, and VANGUARD Project Overview.",
#     "authors": [
#       "Roger Mohr",
#       "R. Buschmann",
#       "Lutz Falkenhagen",
#       "Luc Van Gool",
#       "Reinhard Koch"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "Context and Caterpillars and Structured Documents.",
#     "authors": [
#       "Anne Br\u00fcggemann-Klein",
#       "Stefan Hermann",
#       "Derick Wood"
#     ],
#     "publisher": "Springer",
#     "year": "1998",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1998
#   },
#   {
#     "title": "SOTA-a visualisation tool for ART neural networks.",
#     "authors": [
#       "Guszti Bartfai",
#       "Martin Elliffe",
#       "Peter Wood"
#     ],
#     "publisher": "IEEE",
#     "year": "1993",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1993
#   },
#   {
#     "title": "Designing a Tool for Learning Ada Using Empirical Studies.",
#     "authors": [
#       "Vikki Fix",
#       "Susan Wiedenbeck"
#     ],
#     "publisher": "Psychology of Programming Interest Group",
#     "year": "1992",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "Local exhaustive testing: a software reliability tool.",
#     "authors": [
#       "Thomas Wood",
#       "Keith W. Miller",
#       "Robert E. Noonan"
#     ],
#     "publisher": "ACM",
#     "year": "1992",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "Incl: A Tool to Analyze Include Files.",
#     "authors": [
#       "Kiem-Phong Vo",
#       "Yih-Farn Chen"
#     ],
#     "publisher": "USENIX Association",
#     "year": "1992",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1992
#   },
#   {
#     "title": "A Performance Advisor Tool for Shared-Memory Parallel Programming.",
#     "authors": [
#       "Seon Wook Kim",
#       "Insung Park",
#       "Rudolf Eigenmann"
#     ],
#     "publisher": "Springer",
#     "year": "2000",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 2000
#   },
#   {
#     "title": "Science of Coercion: Communication Research and Psychological Warfare, 1945-1960",
#     "authors": [
#       "Christopher Simpson"
#     ],
#     "publisher": "Oxford University Press",
#     "year": "1994",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1994
#   },
#   {
#     "title": "Determining optimal scales for edge detection using regularization.",
#     "authors": [
#       "Hong Jeong",
#       "Chang-Ik Kim",
#       "Woon-Tack Woo"
#     ],
#     "publisher": "IEEE Computer Society",
#     "year": "1991",
#     "type": "Publication",
#     "key": "Wolle",
#     "year_correct": true,
#     "year_number": 1991
#   }
# ]

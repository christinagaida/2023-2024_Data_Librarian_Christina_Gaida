# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.columns
# Out:
# /tmp/ipykernel_3456/226503331.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Within San Francisco County'],
#       dtype='object')

# %%
x = df['Total Renewals']
df[['Total Renewals', 'Total Checkouts']]
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
print(x)
print(subset)
# Out:
# 0           15
# 1          378
# 2           33
# 3         2140
# 4         1035
#           ...
# 436285       6
# 436286       0
# 436287       0
# 436288       0
# 436289     101
# Name: Total Renewals, Length: 436290, dtype: int64
#         Total Renewals  Total Checkouts
# 0                   15               53
# 1                  378              480
# 2                   33               70
# 3                 2140             3934
# 4                 1035             1118
# ...                ...              ...
# 436285               6                2
# 436286               0                3
# 436287               0                6
# 436288               0                4
# 436289             101              309
#
# [436290 rows x 2 columns]

# %%
df['dummy_variable'] = 5

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# 2                   33     45 to 54 years                n4
# 3                 2140                NaN                o2
# 4                 1035                NaN                o7
# ...                ...                ...               ...
# 436285               6     35 to 44 years               yjj
# 436286               0     10 to 19 years               yjj
# 436287               0     60 to 64 years               ylw
# 436288               0     35 to 44 years               ylw
# 436289             101  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 0                      Bayview                      Mar
# 1                    Excelsior                      Jun
# 2                   Noe Valley                      Jan
# 3                   Ocean View                      Jul
# 4                       Ortega                      Jul
# ...                        ...                      ...
# 436285              Bookmobile                      Oct
# 436286              Bookmobile                      Nov
# 436287              Bookmobile                      Mar
# 436288              Bookmobile                      Sep
# 436289              Bookmobile                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 0                        2023.0                      z
# 1                        2023.0                      z
# 2                        2023.0                      z
# 3                        2023.0                      z
# 4                        2023.0                      z
# ...                         ...                    ...
# 436285                   2022.0                      z
# 436286                   2015.0                      z
# 436287                   2022.0                      z
# 436288                   2020.0                      z
# 436289                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             Email                    True
# 1                             Email                    True
# 2                             Email                    True
# 3                             Email                    True
# 4                             Email                    True
# ...                             ...                     ...
# 436285                        Email                    True
# 436286                        Email                    True
# 436287                        Email                    True
# 436288                        Email                    True
# 436289                        Email                    True
#
#         Year Patron Registered Within San Francisco County  dummy_variable
# 0                         2003                       False               5
# 1                         2003                       False               5
# 2                         2011                       False               5
# 3                         2003                       False               5
# 4                         2003                       False               5
# ...                        ...                         ...             ...
# 436285                    2020                         NaN               5
# 436286                    2011                         NaN               5
# 436287                    2022                         NaN               5
# 436288                    2019                         NaN               5
# 436289                    2003                         NaN               5
#
# [436290 rows x 15 columns]

# %%
import numpy as np

df['is_adult'] = df['Patron Type Definition'] == 'ADULT'
df['log_renewals'] = np.log(df['Total Renewals'] + 1)

# %%
# 'Membership Duration' = ('Circulation Active Year' - 'Year Patron Registered')*12 + 'Circulation Active Month'

# %%
df['Circulation Active Year'] = pd.to_numeric(
  df['Circulation Active Year'], errors='coerce'
)

# %%
df['Circulation Active Year']
# Out:
# 0         2023.0
# 1         2023.0
# 2         2023.0
# 3         2023.0
# 4         2023.0
#            ...
# 436285    2022.0
# 436286    2015.0
# 436287    2022.0
# 436288    2020.0
# 436289    2023.0
# Name: Circulation Active Year, Length: 436290, dtype: float64

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%B"
)

# %%
df['Circulation Active Month']
# Out:
# 0        NaT
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
#           ..
# 436285   NaT
# 436286   NaT
# 436287   NaT
# 436288   NaT
# 436289   NaT
# Name: Circulation Active Month, Length: 436290, dtype: datetime64[ns]

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month
df['Circulation Active Month']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 436285   NaN
# 436286   NaN
# 436287   NaN
# 436288   NaN
# 436289   NaN
# Name: Circulation Active Month, Length: 436290, dtype: float64

# %%
df['Membership Duration'] = (
    df['Circulation Active Year'] - df['Year Patron Registered']
)*12 + df['Circulation Active Month']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 df['Membership Duration'] = (
# ----> 2     df['Circulation Active Year'] - df['Year Patron Registered']
#       3 )*12 + df['Circulation Active Month']
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:224, in arithmetic_op(left, right, op)
#     211 # NB: We assume that extract_array and ensure_wrapped_if_datetimelike
#     212 #  have already been called on `left` and `right`,
#     213 #  and `maybe_prepare_scalar_for_op` has already been called on `right`
#     214 # We need to special-case datetime64/timedelta64 dtypes (e.g. because numpy
#     215 # casts integer dtypes to timedelta64 when operating with timedelta64 - GH#22390)
#     217 if (
#     218     should_extension_dispatch(left, right)
#     219     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)
#     222     # Timedelta/Timestamp and other custom scalars are included in the check
#     223     # because numexpr will fail on it, see GH#31457
# --> 224     res_values = op(left, right)
#     225 else:
#     226     # TODO we should handle EAs consistently and move this check before the if/else
#     227     # (https://github.com/pandas-dev/pandas/issues/41165)
#     228     _bool_arith_check(op, left, right)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:1412, in DatetimeLikeArrayMixin.__sub__(self, other)
#    1410 elif is_integer_dtype(other_dtype):
#    1411     if not is_period_dtype(self.dtype):
# -> 1412         raise integer_op_not_supported(self)
#    1413     obj = cast("PeriodArray", self)
#    1414     result = obj._addsub_int_array_or_scalar(other * obj.freq.n, operator.sub)
#
# TypeError: Addition/subtraction of integers and integer-arrays with DatetimeArray is no longer supported.  Instead of adding/subtracting `n`, use `n * obj.freq`

# %% [markdown]
# Anscheinend funktioniert das mit 3.8 doch nicht :/

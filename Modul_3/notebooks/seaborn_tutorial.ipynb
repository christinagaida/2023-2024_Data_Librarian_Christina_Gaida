# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set()

# use sample to generate a random subsample
df = pd.read_csv("../data/Library_Usage.csv").sample(n=1000)
# Out:
# /tmp/ipykernel_8068/1137232794.py:9: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv").sample(n=1000)

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 277092                 2                   Teen              458
# 420437                 3                 Senior                8
# 373580                 0                  Adult                9
# 415047                 3                 Senior               55
# 249835                 0                  Adult               24
# ...                  ...                    ...              ...
# 287014                 1               Juvenile              564
# 153375                 0                  Adult              198
# 380796                 0                  Adult                0
# 95642                  3                 Senior             2189
# 168604                 0                  Adult              517
#
#         Total Renewals          Age Range Home Library Code  \
# 277092              33     10 to 19 years                r3
# 420437               1  75 years and over                n6
# 373580              15     60 to 64 years                v3
# 415047               3     65 to 74 years                m6
# 249835              29     35 to 44 years                a5
# ...                ...                ...               ...
# 287014             624       0 to 9 years                w2
# 153375             422     55 to 59 years                p9
# 380796               0     25 to 34 years                m8
# 95642              194  75 years and over                 x
# 168604              60     10 to 19 years                n4
#
#        Home Library Definition Circulation Active Month  \
# 277092                Richmond                      Feb
# 420437             North Beach                      Jul
# 373580       Visitacion Valley                      Jul
# 415047                 Mission                      Nov
# 249835                    Anza                      Jul
# ...                        ...                      ...
# 287014             West Portal                      Jul
# 153375                Presidio                      Jul
# 380796             Mission Bay                      Jul
# 95642                     Main                      Jul
# 168604              Noe Valley                      Sep
#
#         Circulation Active Year Notice Preference Code  \
# 277092                   2023.0                      z
# 420437                   2023.0                      z
# 373580                   2023.0                      z
# 415047                   2021.0                      z
# 249835                   2023.0                      z
# ...                         ...                    ...
# 287014                   2023.0                      z
# 153375                   2023.0                      z
# 380796                   2023.0                      z
# 95642                    2023.0                    NaN
# 168604                   2022.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 277092                        Email                    True
# 420437                        Email                    True
# 373580                        Email                    True
# 415047                        Email                    True
# 249835                        Email                    True
# ...                             ...                     ...
# 287014                        Email                    True
# 153375                        Email                    True
# 380796                        Email                    True
# 95642                           NaN                   False
# 168604                        Email                    True
#
#         Year Patron Registered Within San Francisco County
# 277092                    2011                       False
# 420437                    2018                       False
# 373580                    2019                       False
# 415047                    2013                       False
# 249835                    2016                       False
# ...                        ...                         ...
# 287014                    2017                       False
# 153375                    2011                       False
# 380796                    2019                       False
# 95642                     2003                       False
# 168604                    2004                       False
#
# [1000 rows x 14 columns]

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=df)
# Out:
# /home/christina/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=df,
            height=5, aspect=3)
# Einstellen der Plot-Größe
# Out:
# /home/christina/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.savefig('../tutorial.png', dpi=150)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
                hue='Provided Email Address', style='Outside of County', 
                size='Year Patron Registered', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.relplot(x='Total Checkouts', y='Total Renewals',
#       2                 hue='Provided Email Address', style='Outside of County',
#       3                 size='Year Patron Registered', data=df)
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
#     864     variables=plotter.get_semantics(locals()),
#     865     legend=legend,
#     866 )
#     867 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     868 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py:538, in _ScatterPlotter.__init__(self, data, variables, legend)
#     529 def __init__(self, *, data=None, variables={}, legend=None):
#     530
#     531     # TODO this is messy, we want the mapping to be agnostic about
#     532     # the kind of plot to draw, but for the time being we need to set
#     533     # this information so the SizeMapping can use it
#     534     self._default_size_range = (
#     535         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     536     )
# --> 538     super().__init__(data=data, variables=variables)
#     540     self.legend = legend
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `Outside of County` for parameter `style`

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
            size='Year Patron Registered',
            row='Provided Email Address', col='Outside of County', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.relplot(x='Total Checkouts', y='Total Renewals',
#       2             size='Year Patron Registered',
#       3             row='Provided Email Address', col='Outside of County', data=df)
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py:916, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     914 grid_semantics = "row", "col"
#     915 p.semantics = plot_semantics + grid_semantics
# --> 916 p.assign_variables(
#     917     data=data,
#     918     variables=dict(
#     919         x=x, y=y,
#     920         hue=hue, size=size, style=style, units=units,
#     921         row=row, col=col,
#     922     ),
#     923 )
#     925 # Define the named variables for plotting on each facet
#     926 # Rename the variables with a leading underscore to avoid
#     927 # collisions with faceting variable names
#     928 plot_variables = {v: f"_{v}" for v in variables}
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~/anaconda3/lib/python3.8/site-packages/seaborn/_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `Outside of County` for parameter `col`

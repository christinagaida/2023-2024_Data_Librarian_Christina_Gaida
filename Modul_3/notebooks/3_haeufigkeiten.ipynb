# %% [markdown]
# # Häufigkeiten

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df['Age Range'].value_counts() #damit werden die absoluten Häufigkeitstabellen angezeigt
# Out:
# /tmp/ipykernel_5904/3927594286.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
# Age Range
# 25 to 34 years       92669
# 35 to 44 years       81719
# 10 to 19 years       66857
# 45 to 54 years       48319
# 0 to 9 years         32692
# 65 to 74 years       31714
# 20 to 24 years       25381
# 75 years and over    19297
# 55 to 59 years       19076
# 60 to 64 years       17654
# Name: count, dtype: int64

# %%
# relative Häufigkeiten
df['Age Range'].value_counts(normalize=True)
# Out:
# Age Range
# 25 to 34 years       0.212847
# 35 to 44 years       0.187697
# 10 to 19 years       0.153561
# 45 to 54 years       0.110982
# 0 to 9 years         0.075089
# 65 to 74 years       0.072842
# 20 to 24 years       0.058296
# 75 years and over    0.044322
# 55 to 59 years       0.043815
# 60 to 64 years       0.040549
# Name: proportion, dtype: float64

# %%
#Der Modus sind dabei die Merkmalsausprägungen, die die meisten Beobachtungen besitzen
age_mode = df['Age Range'].mode()
age_mode[0]
# Out:
# '25 to 34 years'

# %%
age_mode
# Out:
# 0    25 to 34 years
# Name: Age Range, dtype: object

# %% [markdown]
# ## Aufgabe 3.1 Häufigkeiten

# %% [markdown]
# - Erstelle eine Häufigkeitsverteilung für die Variable 'Year Patron Registered'. Wieviel Prozent der Kunden wurden 2013 im System registriert? Wie viele in den kommenden Jahren? Was fällt Dir auf?
#
# - Wieviel Prozent der Kunden sind zwischen 25 und 34 Jahren?
# - Ersetze die fehlenden Werte in der Spalte Age Range durch den Modus dieser Spalte. Nutze dazu die Funktion DataFrame.fillna (siehe hier für die Dokumentation).
#
# - Denkst Du, es handelt sich dabei um eine gute Methode, fehlende Werte zu ersetzen? Welche anderen Strategien fallen Dir ein?

# %%
df['Year Patron Registered'].value_counts(normalize=True)
# Out:
# Year Patron Registered
# 2022    0.119583
# 2019    0.101515
# 2003    0.094052
# 2021    0.074799
# 2020    0.073369
# 2017    0.067203
# 2018    0.065603
# 2023    0.060249
# 2016    0.049781
# 2015    0.046201
# 2014    0.036593
# 2013    0.030553
# 2012    0.029066
# 2011    0.028348
# 2009    0.026109
# 2010    0.025779
# 2008    0.023154
# 2007    0.014862
# 2006    0.012042
# 2005    0.010910
# 2004    0.010229
# Name: proportion, dtype: float64

# %% [markdown]
# 2013 wurden 3% registriert. In den folgenden Jahren stieg die Anzahl der registrierten Kunden. 2014-2022 insgesammt ca. 78%

# %% [markdown]
# 21,3 % sind zwischen 25-34 Jahren.

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# 2                   33     45 to 54 years                n4
# 3                 2140                NaN                o2
# 4                 1035                NaN                o7
# ...                ...                ...               ...
# 436285               6     35 to 44 years               yjj
# 436286               0     10 to 19 years               yjj
# 436287               0     60 to 64 years               ylw
# 436288               0     35 to 44 years               ylw
# 436289             101  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 0                      Bayview                      Mar
# 1                    Excelsior                      Jun
# 2                   Noe Valley                      Jan
# 3                   Ocean View                      Jul
# 4                       Ortega                      Jul
# ...                        ...                      ...
# 436285              Bookmobile                      Oct
# 436286              Bookmobile                      Nov
# 436287              Bookmobile                      Mar
# 436288              Bookmobile                      Sep
# 436289              Bookmobile                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 0                        2023.0                      z
# 1                        2023.0                      z
# 2                        2023.0                      z
# 3                        2023.0                      z
# 4                        2023.0                      z
# ...                         ...                    ...
# 436285                   2022.0                      z
# 436286                   2015.0                      z
# 436287                   2022.0                      z
# 436288                   2020.0                      z
# 436289                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             Email                    True
# 1                             Email                    True
# 2                             Email                    True
# 3                             Email                    True
# 4                             Email                    True
# ...                             ...                     ...
# 436285                        Email                    True
# 436286                        Email                    True
# 436287                        Email                    True
# 436288                        Email                    True
# 436289                        Email                    True
#
#         Year Patron Registered Within San Francisco County
# 0                         2003                       False
# 1                         2003                       False
# 2                         2011                       False
# 3                         2003                       False
# 4                         2003                       False
# ...                        ...                         ...
# 436285                    2020                         NaN
# 436286                    2011                         NaN
# 436287                    2022                         NaN
# 436288                    2019                         NaN
# 436289                    2003                         NaN
#
# [436290 rows x 14 columns]

# %%
df.fillna({'Age Range':'25 to 34 years'})
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15     25 to 34 years                b2
# 1                  378     25 to 34 years                e9
# 2                   33     45 to 54 years                n4
# 3                 2140     25 to 34 years                o2
# 4                 1035     25 to 34 years                o7
# ...                ...                ...               ...
# 436285               6     35 to 44 years               yjj
# 436286               0     10 to 19 years               yjj
# 436287               0     60 to 64 years               ylw
# 436288               0     35 to 44 years               ylw
# 436289             101  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 0                      Bayview                      Mar
# 1                    Excelsior                      Jun
# 2                   Noe Valley                      Jan
# 3                   Ocean View                      Jul
# 4                       Ortega                      Jul
# ...                        ...                      ...
# 436285              Bookmobile                      Oct
# 436286              Bookmobile                      Nov
# 436287              Bookmobile                      Mar
# 436288              Bookmobile                      Sep
# 436289              Bookmobile                      Jul
#
#        Circulation Active Year Notice Preference Code  \
# 0                       2023.0                      z
# 1                       2023.0                      z
# 2                       2023.0                      z
# 3                       2023.0                      z
# 4                       2023.0                      z
# ...                        ...                    ...
# 436285                  2022.0                      z
# 436286                  2015.0                      z
# 436287                  2022.0                      z
# 436288                  2020.0                      z
# 436289                  2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             Email                    True
# 1                             Email                    True
# 2                             Email                    True
# 3                             Email                    True
# 4                             Email                    True
# ...                             ...                     ...
# 436285                        Email                    True
# 436286                        Email                    True
# 436287                        Email                    True
# 436288                        Email                    True
# 436289                        Email                    True
#
#         Year Patron Registered Within San Francisco County
# 0                         2003                       False
# 1                         2003                       False
# 2                         2011                       False
# 3                         2003                       False
# 4                         2003                       False
# ...                        ...                         ...
# 436285                    2020              25 to 34 years
# 436286                    2011              25 to 34 years
# 436287                    2022              25 to 34 years
# 436288                    2019              25 to 34 years
# 436289                    2003              25 to 34 years
#
# [436290 rows x 14 columns]

# %% [markdown]
# Ich finde die Methode nicht falsch, nur mann kann meistens nur mit einem Wert je Spalte arbeiten.
# Auch eine Variante:
# - df.fillna(df['Age Range'].mode()[0], inplace=True)
